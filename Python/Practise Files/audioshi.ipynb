# %%
from scipy.io import wavfile
from pydub import AudioSegment 
from pydub.playback import play 
import matplotlib.pyplot as plt
# Out:
# /home/mr-arthor/anaconda3/lib/python3.12/site-packages/pydub/utils.py:170: RuntimeWarning: Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work
#   warn("Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work", RuntimeWarning)

# %%
# load the wav file
sample_rate, data =wavfile.read("5MG.wav")
# find the sample rate
print("The sample rate is" +str(sample_rate) + "per seconds")
# find the total length of the file
print("There is the length of file is", str(len(data)) + "seconds")
# find the end point of the wav file
print("Audio end point", str(len(data)/sample_rate))
print(data) 
#Find Maximum amplitude 
print(data.max())
# plot the frequency for the data
plt.plot(data)
plt.show()
# Out:
# /tmp/ipykernel_11711/1422398655.py:2: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sample_rate, data =wavfile.read("5MG.wav")
# The sample rate is44100per seconds
# There is the length of file is 1322253seconds
# Audio end point 29.983061224489795
# [[ 0  0]
#  [ 1  0]
#  [-2  0]
#  ...
#  [ 2  0]
#  [-1  1]
#  [ 1 -1]]
# 14181

# %%
# play the wave file
import simpleaudio as sa
wav_obj = sa.WaveObject.from_wave_file("5MG.wav")
#ply_obj = wav_obj.play()
print("Music is start")
#ply_obj.wait_done()
# Out:
# Music is start

# %%
# merge two wave files

wav_file_1 = AudioSegment.from_file("5MG.wav") 
#play(wav_file_1)
wav_file_2 = AudioSegment.from_file("BAK.wav")
#play(wav_file_2)

# %%
# Merging the two audio files 
wav_file_3 = wav_file_1 + wav_file_2
# play the sound 
#play(wav_file_3)

# %%
# increasing the volume of the audio file in decibles
louder_wav_file = wav_file_1 + 30
#play(louder_wav_file)

# Export louder audio file 
#louder_wav_file.export(out_f = "louder_wav_file.wav",format = "wav")

# %%
# Decreasing the volume of the audio file in decibles
louder_wav_file = wav_file_1 - 15
#play(louder_wav_file)

# %%
# Export louder audio file 
louder_wav_file.export(out_f = "louder_wav_file.wav",format = "wav")
# Out:
# <_io.BufferedRandom name='louder_wav_file.wav'>

# %%
#spiliting the file
b = wav_file_1.split_to_mono() 
print(b) 
print(b[0].channels )
b[0].export(out_f="new.wav",format="wav")
# Out:
# [<pydub.audio_segment.AudioSegment object at 0x70a2b4b53950>, <pydub.audio_segment.AudioSegment object at 0x70a2b4b208f0>]
# 1
# <_io.BufferedRandom name='new.wav'>
